# %% [markdown]
# <a href="https://colab.research.google.com/github/SilvanaCicchitti/TelecomX-parte2/blob/main/TelecomX_parte2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Challenge Telecom X - Parte 2

# %%
import pandas as pd
ruta= '/content/datos_tratados.csv'
datos= pd.read_csv(ruta)
datos
# Out:
#       customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     0002-ORFBO      0  Female              0        1           1     9.0
# 1     0003-MKNFE      0    Male              0        0           0     9.0
# 2     0004-TLHLJ      1    Male              0        0           0     4.0
# 3     0011-IGKFF      1    Male              1        1           0    13.0
# 4     0013-EXCHZ      1  Female              1        1           0     3.0
# ...          ...    ...     ...            ...      ...         ...     ...
# 7027  9987-LUTYD      0  Female              0        0           0    13.0
# 7028  9992-RRAMN      1    Male              0        1           0    22.0
# 7029  9992-UJOEL      0    Male              0        0           0     2.0
# 7030  9993-LHIEB      0    Male              0        1           1    67.0
# 7031  9995-HOTOH      0    Male              0        1           1    63.0
#
# ...
